# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

from scipy.stats import bernoulli, binom, geom, poisson, uniform, expon, norm

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.9147788  2.95735177 2.46314402 2.71927519 2.99044403 2.13215337
#  2.5583979  2.47901342 2.41632097 2.21019134]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def random_generator(bott, ceil, count):
    range1 = uniform.rvs(size=count)
    a = bott    
    b = ceil
    random_range = a+(b-a)*range1
    return random_range

# %%
rando1 = random_generator(10, 15, 100)
rando2 = random_generator(10, 60, 1000)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(rando1, bins = 10)
plt.xlabel("Values")
plt.ylabel("Count")
plt.ylim(0, 100)
plt.title("Uniform Random number from 10 to 15")
plt.show()

# %%
plt.hist(rando2, bins = 10)
plt.xlabel("Values")
plt.ylabel("Count")
plt.ylim(0, 100)
plt.title("Uniform Random number from 10 to 60")
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
#the one with more sampples is the most uniform, indicating it is closer to reality

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def normal_random_generator(avg, std, count):
    normal_randos = np.random.normal(avg, std, count)
    return normal_randos

# %%
rando3 = normal_random_generator(10, 1, 1000)
rando4 = normal_random_generator(10, 50, 1000)

# %%
plt.hist(rando3, bins = 100)
plt.xlabel("Values")
plt.ylabel("Count")
plt.title("Random numbers - normal 01")
plt.show()

# %%
plt.hist(rando4, bins = 100)
plt.xlabel("Values")
plt.ylabel("Count")
plt.title("Random numbers - normal 01")
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here: I'm sorry, I don't see much difference other than the range. The std is higher but the mean is the same.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
vehicles = pd.read_csv("/Users/camilaschroeder/Desktop/DATA/Week6/day2/lab-probability-distributions/your-code/vehicles.csv")

vehicles.head(5)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
plt.hist(vehicles["Fuel Barrels/Year"], bins = 50)
plt.title("Fuel Barrels / Year")
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.hist(vehicles["CO2 Emission Grams/Mile"], bins = 50)
plt.title("CO2 Emission Grams/Mile")
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
plt.hist(vehicles["Combined MPG"], bins = 50)
plt.title("Combined MPG")
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# you answer here: Combined MPG

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with a mean of 1 and 100 and a size of 1000.
#
# 1. Plot the distributions as histograms with the number of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def generate_exponential_random_numbers(a, b):
    return np.random.exponential(scale=a, size=b)

# %%
expo_mean1 = generate_exponential_random_numbers(1, 1000)
expo_mean1
# Out:
# array([1.45332151e+00, 1.52771741e-01, 4.81832443e-01, 1.31316294e-01,
#        1.52068139e+00, 6.62371781e-01, 3.72781344e-01, 2.84568599e+00,
#        1.84085576e+00, 2.66912485e+00, 2.24232408e+00, 1.88229695e+00,
#        6.19697245e-01, 4.13471690e-01, 1.22730000e+00, 2.86518133e-01,
#        2.96038860e-01, 5.25168528e-02, 1.77133331e+00, 1.75261214e+00,
#        1.87484205e+00, 3.74586053e-01, 5.29558970e-01, 8.16119302e-01,
#        5.09388122e-01, 6.27189182e-02, 8.15267275e-01, 3.91555913e-02,
#        5.98211032e-01, 1.57465348e+00, 9.44297120e-01, 9.49388044e-03,
#        1.46418023e+00, 1.45121881e+00, 1.21902325e-01, 2.44461760e-01,
#        2.12255987e-01, 3.10744623e-01, 4.24571328e-01, 9.79027384e-01,
#        4.12151033e+00, 4.65289779e-01, 1.00001467e+00, 8.49665474e-01,
#        1.11281606e+00, 6.37445416e-02, 6.56237708e-01, 1.53546672e-01,
#        4.37815874e-01, 1.64006841e+00, 6.98213255e-01, 2.36492026e+00,
# ...

# %%
expo_mean2 = generate_exponential_random_numbers(1/10, 1000)
expo_mean2
# Out:
# array([4.69723086e-02, 1.64622375e-02, 1.56028185e-01, 1.36074329e-01,
#        9.41340089e-02, 6.96654168e-02, 9.92748965e-02, 3.41994478e-02,
#        2.32895040e-01, 2.89049836e-02, 2.55502278e-01, 1.49794562e-01,
#        1.74196999e-01, 1.56631492e-01, 2.11300190e-02, 8.80820541e-03,
#        1.80471391e-01, 8.93480579e-03, 1.71106581e-01, 2.76268776e-01,
#        2.35208589e-01, 2.11703186e-01, 1.30005202e-01, 4.06914950e-02,
#        4.23679473e-02, 4.33063446e-02, 8.22632653e-02, 1.98952605e-02,
#        1.00461737e-01, 1.43223783e-01, 4.50494607e-02, 4.63043113e-02,
#        1.30622599e-01, 2.36831978e-02, 1.37307792e-01, 8.32559545e-02,
#        1.89638848e-02, 4.71820479e-02, 7.03113403e-02, 1.08512196e-01,
#        2.10993257e-01, 4.37487605e-02, 4.78106734e-02, 2.15423630e-01,
#        3.27936808e-02, 2.09856966e-01, 6.02424870e-02, 1.99063500e-02,
#        3.27542648e-02, 5.76153870e-02, 6.52314841e-02, 6.54978389e-02,
# ...

# %%
plt.hist(expo_mean1, bins = 100)
plt.ylim(0, 100)
plt.show()

# %%
plt.hist(expo_mean2, bins = 100)
plt.ylim(0, 100)
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here: there is more concentration of data in the smaller part of the sample, for the 10 mean.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
mean_time = 10 
lambd = 1 / mean_time

prob_less15_bank = 1 - np.exp(-lambd * mean_time)   

prob_less15_bank
# Out:
# 0.6321205588285577

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
prob_more_15_bank = np.exp(-(1/15)*15)

prob_more_15_bank = 1- expon.cdf(15, 1/15)

prob_more_15_bank
# Out:
# 3.2699095287025415e-07
